# %% [markdown]
# # Horizontal Pong — Training Analysis & Comparison
#
# This notebook loads training logs and produces:
# 1. Learning curves (reward vs episodes) for both agents.
# 2. Ball hits per episode comparison.
# 3. Reward variance / stability analysis.
# 4. Steps-to-threshold comparison (>15 hits).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# TODO: Load training logs
# ac_log = pd.read_csv("../artifacts/train_log_ac.csv")
# rf_log = pd.read_csv("../artifacts/train_log_reinforce.csv")

# %%
# TODO: Plot learning curves — sliding-window average reward (window=100)

# %%
# TODO: Plot average hits per episode

# %%
# TODO: Plot reward variance over training

# %%
# TODO: Compute and display steps-to-threshold (>15 mean hits) for each agent
